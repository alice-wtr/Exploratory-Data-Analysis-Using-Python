# %%
s = input("Enter the sentence: ")
tutu = s.split()

for t in tutu:
  if t[0] == 's':
    print(t)
# Out:
# Enter the sentence: Print only the words that start with s in this sentence
# start
# s
# sentence

# %%
for i in range(6):
  print(2*i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
new = []
for i in range(1, 51):
  if i%3 == 0:
    new = new + [i]

print(new)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]

# %%
s = input("Enter your sentence: ")

tutu = s.split()

for w in tutu:
  if len(w)%2 == 0:
    print(f"{w} - even!")
# Out:
# Enter your sentence: Print every word in this sentence that has an even number of letters
# word - even!
# in - even!
# this - even!
# sentence - even!
# that - even!
# an - even!
# even - even!
# number - even!
# of - even!

# %%
for i in range(1,101):

  if i%15 == 0:
    print("fizzbuzz")

  elif i%3 == 0:
    print("fizz")

  elif i%5 == 0:
    print("buzz")

  else:
    print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %%
s = input("Enter your sentence: ")
tutu = s.split()

final = []
for i in tutu:
  final = final + [i[0]]

print(final)
# Out:
# Enter your sentence: Create a list of the first letters of every word in this string
# ['C', 'a', 'l', 'o', 't', 'f', 'l', 'o', 'e', 'w', 'i', 't', 's']
